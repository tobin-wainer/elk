# %%
import astropy.units as u
from elk.ensemble import EnsembleLC

c = EnsembleLC(output_path="../../output",
               identifier='NGC 419',
               location='23.58271, +61.1236',
               radius=.046,
               cluster_age=7.75,
               spline_knots=,
               cutout_size=10,
               debug=True,
               verbose=True,
               ignore_previous_downloads=True,
               minimize_memory=True)

c.lightcurves_summary_file()

print(c.lcs)
# Out:
# NGC 419 has 4 observations
# Starting Quality Tests for Observation: 0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 16
#       2 from elk.ensemble import EnsembleLC
#       4 c = EnsembleLC(output_path="../../output",
#       5                identifier='NGC 419',
#       6                location='23.58271, +61.1236',
#    (...)
#      13                ignore_previous_downloads=True,
#      14                minimize_memory=True)
# ---> 16 c.lightcurves_summary_file()
#      18 print(c.lcs)
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/elk/ensemble.py:355, in EnsembleLC.lightcurves_summary_file(self)
#     352 # if data is available and the lightcurves have not yet been calculated
#     353 if self.has_tess_data() and self.lcs == []:
#     354     # download and correct lightcurves
# --> 355     self.get_lcs()
#     357     # clear out the cache after we're done making lightcurves
#     358     if self.minimize_memory:
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/elk/ensemble.py:282, in EnsembleLC.get_lcs(self)
#     279     self.n_bad_quality += 1
#     280     continue
# --> 282 lc.correct_lc()
#     284 scattered_light_test = self.scattered_light(lc.quality_tpfs, lc.full_model_normalized)
#     285 if scattered_light_test:
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/elk/lightcurve.py:518, in TESSCutLightcurve.correct_lc(self)
#     516     self.dm = lk.DesignMatrixCollection([pca_dm, cbv_dm_use])
#     517 else:
# --> 518     spline_dm1 = lk.designmatrix.create_spline_matrix(self.quality_tpfs.time.value,
#     519                                                       n_knots=self.spline_knots)
#     520     self.dm = lk.DesignMatrixCollection([pca_dm, cbv_dm_use, spline_dm1])
#     522 full_model, systematics_model, self.full_model_normalized = np.ones((3, *self.quality_tpfs.shape))
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/lightkurve/correctors/designmatrix.py:984, in create_spline_matrix(x, n_knots, knots, degree, name, include_intercept)
#     980 else:
#     981     dm_formula = "bs(x, df={}, degree={}, include_intercept={}) - 1" "".format(
#     982         n_knots, degree, include_intercept
#     983     )
# --> 984     spline_dm = np.asarray(dmatrix(dm_formula, {"x": x}))
#     985     df = pd.DataFrame(
#     986         spline_dm, columns=["knot{}".format(idx + 1) for idx in range(n_knots)]
#     987     )
#     988 return DesignMatrix(df, name=name)
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/patsy/highlevel.py:290, in dmatrix(formula_like, data, eval_env, NA_action, return_type)
#     227 """Construct a single design matrix given a formula_like and data.
#     228
#     229 :arg formula_like: An object that can be used to construct a design
#    (...)
#     287    The ``NA_action`` argument.
#     288 """
#     289 eval_env = EvalEnvironment.capture(eval_env, reference=1)
# --> 290 (lhs, rhs) = _do_highlevel_design(formula_like, data, eval_env,
#     291                                   NA_action, return_type)
#     292 if lhs.shape[1] != 0:
#     293     raise PatsyError("encountered outcome variables for a model "
#     294                         "that does not expect them")
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/patsy/highlevel.py:164, in _do_highlevel_design(formula_like, data, eval_env, NA_action, return_type)
#     162 def data_iter_maker():
#     163     return iter([data])
# --> 164 design_infos = _try_incr_builders(formula_like, data_iter_maker, eval_env,
#     165                                   NA_action)
#     166 if design_infos is not None:
#     167     return build_design_matrices(design_infos, data,
#     168                                  NA_action=NA_action,
#     169                                  return_type=return_type)
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/patsy/highlevel.py:66, in _try_incr_builders(formula_like, data_iter_maker, eval_env, NA_action)
#      64 if isinstance(formula_like, ModelDesc):
#      65     assert isinstance(eval_env, EvalEnvironment)
# ---> 66     return design_matrix_builders([formula_like.lhs_termlist,
#      67                                    formula_like.rhs_termlist],
#      68                                   data_iter_maker,
#      69                                   eval_env,
#      70                                   NA_action)
#      71 else:
#      72     return None
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/patsy/build.py:689, in design_matrix_builders(termlists, data_iter_maker, eval_env, NA_action)
#     687     for term in termlist:
#     688         all_factors.update(term.factors)
# --> 689 factor_states = _factors_memorize(all_factors, data_iter_maker, eval_env)
#     690 # Now all the factors have working eval methods, so we can evaluate them
#     691 # on some data to find out what type of data they return.
#     692 (num_column_counts,
#     693  cat_levels_contrasts) = _examine_factor_types(all_factors,
#     694                                                factor_states,
#     695                                                data_iter_maker,
#     696                                                NA_action)
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/patsy/build.py:370, in _factors_memorize(factors, data_iter_maker, eval_env)
#     368         factor.memorize_chunk(state, which_pass, data)
#     369 for factor in list(memorize_needed):
# --> 370     factor.memorize_finish(factor_states[factor], which_pass)
#     371     if which_pass == passes_needed[factor] - 1:
#     372         memorize_needed.remove(factor)
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/patsy/eval.py:565, in EvalFactor.memorize_finish(self, state, which_pass)
#     563 def memorize_finish(self, state, which_pass):
#     564     for obj_name in state["pass_bins"][which_pass]:
# --> 565         state["transforms"][obj_name].memorize_finish()
#
# File ~/opt/anaconda3/envs/elk/lib/python3.10/site-packages/patsy/splines.py:185, in BS.memorize_finish(self)
#     183     n_inner_knots += 1
#     184 if n_inner_knots < 0:
# --> 185     raise ValueError("df=%r is too small for degree=%r and "
#     186                      "include_intercept=%r; must be >= %s"
#     187                      % (args["df"], args["degree"],
#     188                         args["include_intercept"],
#     189                         # We know that n_inner_knots is negative;
#     190                         # if df were that much larger, it would
#     191                         # have been zero, and things would work.
#     192                         args["df"] - n_inner_knots))
#     193 if args["knots"] is not None:
#     194     if len(args["knots"]) != n_inner_knots:
#
# ValueError: df=1 is too small for degree=3 and include_intercept=True; must be >= 4

# %%
c.lcs[2].plot()
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Lightcurve for Sector 25'}, xlabel='Time $\\rm [days]$', ylabel='Flux $[e / {\\rm s}]$'>)
