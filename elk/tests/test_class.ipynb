# %%
import astropy.units as u
from elk.ensemble import EnsembleLC

c = EnsembleLC(output_path="../../output",
               identifier='NGC 419',
               location='23.58271, +61.1236',
               radius=.046,
               cluster_age=7.75,
               spline_knots=5,
               cutout_size=10,
               debug=True,
               verbose=True,
               ignore_previous_downloads=True,
               minimize_memory=True)

c.lightcurves_summary_file()

print(c.lcs)
# Out:
# NGC 419 has 4 observations
# Starting Quality Tests for Observation: 0
# 100%|██████████████████████████████| 100/100 [00:03<00:00, 31.24it/s]
#   Passed Quality Tests
# Starting Quality Tests for Observation: 1
# 100%|██████████████████████████████| 100/100 [00:02<00:00, 37.34it/s]
#   Passed Quality Tests
# Starting Quality Tests for Observation: 2
# 100%|██████████████████████████████| 100/100 [00:03<00:00, 28.14it/s]
#   Passed Quality Tests
# Starting Quality Tests for Observation: 3
# 100%|██████████████████████████████| 100/100 [00:09<00:00, 10.75it/s]
#   Passed Quality Tests
# [<BasicLightcurve: TESS Sector 18, 1103 timesteps>, <BasicLightcurve: TESS Sector 24, 1224 timesteps>, <BasicLightcurve: TESS Sector 25, 1167 timesteps>, <BasicLightcurve: TESS Sector 58, 11692 timesteps>]

# %%
# Out:
# (<Figure size 640x480 with 1 Axes>,
#  <Axes: title={'center': 'Lightcurve for Sector 25'}, xlabel='Time $\\rm [days]$', ylabel='Flux $[e / {\\rm s}]$'>)
